# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hv = np.load("human_vels.npy")
rv = np.load("robot_vels.npy")

# %%
plt.plot([i for i in range(len(hv))],hv,color='red')
plt.plot([i for i in range(len(rv))],rv)

# %%
plt.plot([i for i in range(len(hv))],np.sqrt((hv-rv)**2))
